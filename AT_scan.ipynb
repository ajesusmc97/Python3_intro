# %%
import matplotlib.pyplot as plt 
import numpy as np 
from mpl_toolkits.mplot3d import Axes3D 
import pandas as pd

# %% [markdown]
# ## Superifice de energia potencial para la doble transferencia de protón en el par canónico WA Adenina- Timina

# %%
datos = ["avance","c1","c2","energia"]

# %%
adenina = pd.read_csv("adenina.csv", usecols=datos)
adenina
# Out:
#      avance        c1         c2   energia
# 0         0  0.000000   0.000000  0.000000
# 1         1  0.000000   0.006275  0.006275
# 2         2  0.006275   0.012550  0.012550
# 3         3  0.018825   0.018825  0.018825
# 4         4  0.031375   0.031375  0.025100
# ..      ...       ...        ...       ...
# 175     175       NaN  15.323770       NaN
# 176     176       NaN  15.311220       NaN
# 177     177       NaN  15.304945       NaN
# 178     178       NaN  15.304945       NaN
# 179     179       NaN  15.298669       NaN
#
# [180 rows x 4 columns]

# %%
Z= adenina["energia"]
X=adenina["c1"]
Y=adenina["c2"]
Z
# Out:
# 0      0.000000
# 1      0.006275
# 2      0.012550
# 3      0.018825
# 4      0.025100
#          ...
# 175         NaN
# 176         NaN
# 177         NaN
# 178         NaN
# 179         NaN
# Name: energia, Length: 180, dtype: float64

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.gca(projection='3d')
PES= fig = plt.figure(figsize=(15,10))
ax.scatter3D(X,Y,Z)
plt.title("PES para la DPT en el par AT (gas)")
plt.xlabel("Coordenada 1")
plt.ylabel("Coordenada 2")
#plt.zlabel("Energía (kcal/mol")
plt.show()
