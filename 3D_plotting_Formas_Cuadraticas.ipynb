# %% [markdown]
# # Graficación 3D con Python Matplotlib.
#
# ## Parte I. Superficie de una forma cuadrática
#
# En este ejercicio se graficará la forma cuadrática:
#
# $$ Q(x,y) = ax^2 + bxy + cy^2 $$
# con las herramientas de Matplotlib

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np
import matplotlib 
matplotlib.rcParams['text.usetex'] = True  #Tipografía Serif de LATeX 
matplotlib.rc('xtick', labelsize=12) 
matplotlib.rc('ytick', labelsize=12)   #Tamaño de los ejes 

fig = plt.figure(figsize=(15,10))
ax = fig.gca(projection='3d')

#Datos
a= 10
b= 1
c= 10
X =np.arange(-10, 10, 0.25)
Y = np.arange(-10, 10, 0.25)
X, Y = np.meshgrid(X, Y)
Z = a*X**2 + b*X*Y + c*Y**2


#Plotear

superficie = ax.plot_surface(X,Y,Z, cmap=cm.coolwarm, linewidth=1 , cstride=1 , rstride = 1)
plt.title("Gráfica de una forma cuadrática",size=20)
plt.xlabel("Valores de x",size=20)
plt.ylabel("Valores de y",size=20 )
#fig.colorbar(superficie,shrink =0.5,aspect=5)  
plt.show()

# %% [markdown]
# # Parte II . Mapas de contorno
#
# Ahora serán graficados los mapas de contorno de la forma cuadrática

# %%
fig,ax=plt.subplots(1,1 , figsize=(10,8))
cp = ax.contourf(X, Y, Z, cmap=cm.coolwarm)
# fig.colorbar(cp) # Barra de color 
#ax.clabel(cp)
ax.set_title('Mapas de contorno de la forma cuadrática',size=14)
ax.set_xlabel('x (cm)', size=20)
ax.set_ylabel('y (cm)', size=20)
plt.show()

# %% [markdown]
# # Parte III.  Graficando una serie de puntos
#
# Serán graficados los datos aleatorios de tres listas

# %%
A = np.arange(-50,50,0.1)
B=np.arange(-50,50,0.1)
C = np.arange(-60,40,0.1)
len(C)
# Out:
# 1000

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.gca(projection='3d')
ab = ax.scatter(A,B,C)
